# %% [markdown]
# <a href="https://colab.research.google.com/github/KaylumCassidy/CA/blob/main/17_WebScrawl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Crawl A Web Page

# %% [markdown]
# **Web scraping**, often called web crawling or web spidering, or “programmatically going over a collection of web pages and extracting data,” is a powerful tool for working with data on the web.
#
# With a web crawler, you can mine data about a set of products, get a large corpus of text or quantitative data to play around with, get data from a site without an official API, or just satisfy your own personal curiosity.
#
# In this tutorial, you’ll learn about the fundamentals of the scraping and spidering process as you explore a playful data set. We’ll use **BrickSet**, a community-run site that contains information about LEGO sets. By the end of this tutorial, you’ll have a fully functional Python web crawler that walks through a series of pages on **Brickset** and extracts data about LEGO sets from each page, displaying the data to your screen.
#
# The crawler will be easily expandable so you can tinker around with it and use it as a foundation for your own projects scraping data from the web.

# %% [markdown]
# ## Step 1 — Creating a Basic Review
# Scraping is a two step process:<br>
# 1. You systematically find and download web pages.<br>
# 2. You take those web pages and extract information from them.<br>

# %%
# Let’s create a new folder "brickset-crawler" for our project. You can do this in the terminal by running:

# !mkdir brickset-crawler

# %% [markdown]
# Let's start from http://brickset.com/sets/year-2016 <br>
# <img src="images/Bricksets.jpg"><br>

# %% [markdown]
# ## Step 2: Crawling all links for  product items (on ONE category page)

# %% [markdown]
# Let's take one page for extracting content: http://brickset.com/sets/year-2016 <br>
# Download the HTML source code of the category page

# %%
start_urls = 'http://brickset.com/sets/year-2016'

# Write you code here to download content of HTML page
import urllib.request
response = urllib.request.urlopen(start_urls)
raw_html = response.read().decode("utf-8")

# Write you code here to parse HTML page
from bs4 import BeautifulSoup
soup = BeautifulSoup(raw_html, 'html.parser')

# %% [markdown]
# Identify the product box for each brick item on category. Print out the title and link of detail page.<br>
# For example, link for **10251: Brick Bank** is https://brickset.com/sets/10251-1/Brick-Bank <br>
# <img src="images/BrickBankTitle.jpg"><br>
# Save them into list **lst_productlinks**

# %%
import pprint
lst_productlinks = []


secbox = soup.find("section", {"class":"setlist"})
print(len(secbox.find_all("article", {"class": "set"})))
for divbox in secbox.find_all("article", {"class":"set"}):
  try:
      title = divbox.find("h1").get_text()
      href = divbox.find("a").get("href")
      stext = divbox.get_text().strip()
      print(title, "=>", href)
      lst_productlinks.append([title,href])
  except:
      pass
# Out:
# 25
# Brick Bank => https://images.brickset.com/sets/large/10251-1.jpg?201510121127
# Volkswagen Beetle => https://images.brickset.com/sets/large/10252-1.jpg?201606140214
# Big Ben => https://images.brickset.com/sets/large/10253-1.jpg?201605190256
# Winter Holiday Train => https://images.brickset.com/sets/large/10254-1.jpg?201608110306
# XL Creative Brick Box => https://images.brickset.com/sets/large/10654-1.jpg?201609271134
# Creative Building Set => https://images.brickset.com/sets/large/10702-1.jpg?201511230710
# Creative Building Basket => https://images.brickset.com/sets/large/10705-1.jpg?201605201119
# Police Helicopter Chase => https://images.brickset.com/sets/large/10720-1.jpg?201601050913
# Iron Man vs. Loki => https://images.brickset.com/sets/large/10721-1.jpg?201601050913
# Snake Showdown => https://images.brickset.com/sets/large/10722-1.jpg?201601050913
# Ariel's Dolphin Carriage => https://images.brickset.com/sets/large/10723-1.jpg?201601050913
# ['Around the World', 'https://images.brickset.com/sets/large/10805-1.jpg?201601050913']
# ['Horses', 'https://images.brickset.com/sets/large/10806-1.jpg?201511230710']
# ['Horse Trailer', 'https://images.brickset.com/sets/large/10807-1.jpg?201511230710']
# ['Little Plane', 'https://images.brickset.com/sets/large/10808-1.jpg?201511230710']

# %% [markdown]
# ## Step 3 — Extracting Data from a Page
#
# Let’s give it some data to extract.<br>
# <img src="images/BrickBank.jpg">

# %% [markdown]
# Let's extract information for each product:<br>
#  -  Title
#  -  Link
#  -  Theme
#  -  Subtheme
#  -  Pieces
#  -  Packaging
#  -  Price
#  -  Set Type

# %%
import pprint
# Write you code here to extract information
secbox = soup.find("section", {"class":"setlist"})
print(len(secbox.find_all("article", {"class": "set"})))
for divbox in secbox.find_all("article", {"class":"set"}):
  try:
      title = divbox.find("h1").get_text()
      href = divbox.find("a").get("href")
      theme = divbox.find("div", {"class":"tags"}).find_all("a")[1].get_text()
      subtheme = divbox.find("div", {"class":"tags"}).find_all("a")[2].get_text()
      year = divbox.find("div", {"class":"tags"}).find_all("a")[-1].get_text()

      pieces = divbox.find("div", {"class":"col"}).find_all("a")[0].get_text()
      packaging = divbox.find("div", {"class":"col"}).find_all("dd")[5].get_text()

      kpos = -1
      for k, box in enumerate(divbox.find_all("dt")):
        if box.get_text().find("Related") >= 0:
          kpos = k
          break
      relatedset = ""
      if kpos >= 0:
        relatedset = divbox.find_all("dd")[kpos].get_text()
        #Option1:
        relatedset = relatedset[relatedset.find("with")+5:] if relatedset.find("with")>0 else relatedset
        #Option2:
        l = relatedset.split()
        l = [x for x in l if x[-2:]=="-1"]
        relatedset = " ".join(l)
        #Option3: relatedset = " ".join([t for t in relatedset.split() if t[-2:]=="-1"])

      for pricebox in divbox.find("div", {"class":"col"}).find_all("dd"):
        if pricebox.get_text().find("$") >=0:
          price = pricebox.get_text()
          break


      #set_type = divbox.find("div", {"class":"col"}).find_all("dt")[].get_text()
      lst_productlinks.append([title,href,theme,subtheme,pieces,year,packaging,price,relatedset])
  except:
      pass

  oneproduct = {}
  oneproduct["Title"] = title
  oneproduct["Link"] = href
  oneproduct["Theme"] = theme
  oneproduct["Subtheme"] = subtheme
  oneproduct["Pieces"] = pieces
  oneproduct["Year"] = year
  oneproduct["Packaging"] = packaging
  oneproduct["Price"] = price
  oneproduct["Set Type"] = relatedset

  pprint.pprint(oneproduct)
  #break
# Out:
# 25
# {'Link': 'https://images.brickset.com/sets/large/10251-1.jpg?201510121127',
#  'Packaging': 'Box',
#  'Pieces': '2380',
#  'Price': '$169.99, €149.99 | More',
#  'Set Type': '10182-1 10185-1 10190-1 10197-1 10232-1',
#  'Subtheme': 'Modular Buildings Collection',
#  'Theme': 'Creator Expert',
#  'Title': 'Brick Bank',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10252-1.jpg?201606140214',
#  'Packaging': '20',
#  'Pieces': '1167',
#  'Price': '$99.99, €87.72 | More',
#  'Set Type': '40252-1',
#  'Subtheme': 'Vehicles',
#  'Theme': 'Creator Expert',
#  'Title': 'Volkswagen Beetle',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10253-1.jpg?201605190256',
#  'Packaging': '19',
#  'Pieces': '4163',
#  'Price': '$249.99, €219.99 | More',
#  'Set Type': '',
#  'Subtheme': 'Landmarks',
#  'Theme': 'Creator Expert',
#  'Title': 'Big Ben',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10254-1.jpg?201608110306',
#  'Packaging': 'Box',
#  'Pieces': '734',
#  'Price': '$99.99, €89.99 | More',
#  'Set Type': '10259-1',
#  'Subtheme': 'Winter Village Collection',
#  'Theme': 'Creator Expert',
#  'Title': 'Winter Holiday Train',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10654-1.jpg?201609271134',
#  'Packaging': 'Box',
#  'Pieces': '1600',
#  'Price': '$99.99, €89.99 | More',
#  'Set Type': '10259-1',
#  'Subtheme': 'Creative Box',
#  'Theme': 'Classic',
#  'Title': 'XL Creative Brick Box',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10702-1.jpg?201511230710',
#  'Packaging': '10',
#  'Pieces': '583',
#  'Price': '$29.99, €24.99 | More',
#  'Set Type': '',
#  'Subtheme': 'Creative Building',
#  'Theme': 'Classic',
#  'Title': 'Creative Building Set',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10705-1.jpg?201605201119',
#  'Packaging': '8',
#  'Pieces': '1000',
#  'Price': '$59.99, €39.99 | More',
#  'Set Type': '',
#  'Subtheme': 'Creative Building',
#  'Theme': 'Classic',
#  'Title': 'Creative Building Basket',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10720-1.jpg?201601050913',
#  'Packaging': 'Box',
#  'Pieces': '63',
#  'Price': '$9.99, €9.99 | More',
#  'Set Type': '',
#  'Subtheme': 'City',
#  'Theme': 'Juniors',
#  'Title': 'Police Helicopter Chase',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10721-1.jpg?201601050913',
#  'Packaging': 'Box',
#  'Pieces': '66',
#  'Price': '$12.99, €12.99 | More',
#  'Set Type': '',
#  'Subtheme': 'Marvel Super Heroes',
#  'Theme': 'Juniors',
#  'Title': 'Iron Man vs. Loki',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10722-1.jpg?201601050913',
#  'Packaging': 'Box',
#  'Pieces': '92',
#  'Price': '$14.99, €14.99 | More',
#  'Set Type': '',
#  'Subtheme': 'Ninjago',
#  'Theme': 'Juniors',
#  'Title': 'Snake Showdown',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10723-1.jpg?201601050913',
#  'Packaging': 'Box',
#  'Pieces': '70',
#  'Price': '$14.99, €14.99 | More',
#  'Set Type': '',
#  'Subtheme': 'Disney Princess',
#  'Theme': 'Juniors',
#  'Title': "Ariel's Dolphin Carriage",
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10724-1.jpg?201605201119',
#  'Packaging': 'Box',
#  'Pieces': '164',
#  'Price': '$19.99, €19.99 | More',
#  'Set Type': '',
#  'Subtheme': 'DC Comics Super Heroes',
#  'Theme': 'Juniors',
#  'Title': 'Batman & Superman vs. Lex Luthor',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10725-1.jpg?201601050913',
#  'Packaging': 'Box',
#  'Pieces': '172',
#  'Price': '$29.99, €34.99 | More',
#  'Set Type': '',
#  'Subtheme': 'Ninjago',
#  'Theme': 'Juniors',
#  'Title': 'Lost Temple',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10726-1.jpg?201605201119',
#  'Packaging': 'Box',
#  'Pieces': '58',
#  'Price': '$12.99, €9.99 | More',
#  'Set Type': '',
#  'Subtheme': 'Friends',
#  'Theme': 'Juniors',
#  'Title': "Stephanie's Horse Carriage",
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10727-1.jpg?201605201119',
#  'Packaging': 'Box',
#  'Pieces': '136',
#  'Price': '$19.99, €19.99 | More',
#  'Set Type': '',
#  'Subtheme': 'Friends',
#  'Theme': 'Juniors',
#  'Title': "Emma's Ice Cream Truck",
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10728-1.jpg?201605201119',
#  'Packaging': 'Box',
#  'Pieces': '173',
#  'Price': '$29.99, €29.99 | More',
#  'Set Type': '',
#  'Subtheme': 'Friends',
#  'Theme': 'Juniors',
#  'Title': "Mia's Vet Clinic",
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10729-1.jpg?201601050913',
#  'Packaging': 'Box',
#  'Pieces': '116',
#  'Price': '$24.99, €24.99 | More',
#  'Set Type': '',
#  'Subtheme': 'Disney Princess',
#  'Theme': 'Juniors',
#  'Title': "Cinderella's Carriage",
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10801-1.jpg?201511230710',
#  'Packaging': 'Box',
#  'Pieces': '13',
#  'Price': '$24.99, €24.99 | More',
#  'Set Type': '',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Baby Animals',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10802-1.jpg?201511230710',
#  'Packaging': 'Box',
#  'Pieces': '18',
#  'Price': '$19.99, €19.99 | More',
#  'Set Type': '',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Savanna',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10803-1.jpg?201511230710',
#  'Packaging': 'Box',
#  'Pieces': '40',
#  'Price': '$29.99, €29.99 | More',
#  'Set Type': '',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Arctic',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10804-1.jpg?201511230710',
#  'Packaging': 'Box',
#  'Pieces': '86',
#  'Price': '$49.99, €59.99 | More',
#  'Set Type': '',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Jungle',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10805-1.jpg?201601050913',
#  'Packaging': 'Box',
#  'Pieces': '163',
#  'Price': '$99.99, €99.99 | More',
#  'Set Type': '',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Around the World',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10806-1.jpg?201511230710',
#  'Packaging': 'Box',
#  'Pieces': '20',
#  'Price': '$14.99, €14.99 | More',
#  'Set Type': '',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Horses',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10807-1.jpg?201511230710',
#  'Packaging': 'Box',
#  'Pieces': '15',
#  'Price': '$19.99, €19.99 | More',
#  'Set Type': '',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Horse Trailer',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10808-1.jpg?201511230710',
#  'Packaging': 'Box',
#  'Pieces': '13',
#  'Price': '$9.99, €9.99 | More',
#  'Set Type': '',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Little Plane',
#  'Year': '2016'}

# %% [markdown]
# # Crawling Multiple Pages
#
# We’ve successfully extracted data from that initial page, but we’re not progressing past it to see the rest of the results. The whole point of a spider is to detect and traverse links to other pages and grab data from those pages too.

# %% [markdown]
# ## Step 1: Crawling all links for category pages

# %% [markdown]
# Let's start from http://brickset.com/sets/year-2016 <br>
# <img src="images/NavigateLinks.jpg"><br>
# So,estimate:<br>
#  -  How many pages do we have from this category?
#  -  How many pages do we have for each year?<br>
# List all of these links and put into a list

# %%
import requests
from bs4 import BeautifulSoup

# Start URL
start_url = "http://brickset.com/sets/year-2016"

# Send a GET request to the URL
response = requests.get(start_url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all links to category pages
    category_links = soup.find_all('a', class_='year')

    # Store the links in a list
    category_links_list = [link['href'] for link in category_links]

    # Print the number of pages and the list of links
    print(f"Number of pages in the category: {len(category_links_list)}")
    print("List of category links:")
    for link in category_links_list:
        print(link)

    # You can further loop through each year page to get more specific details
    for year_link in category_links_list:
        year_url = f"http://brickset.com{year_link}"
        year_response = requests.get(year_url)

        if year_response.status_code == 200:
            year_soup = BeautifulSoup(year_response.text, 'html.parser')

            # Find all links to sets for each year
            set_links = year_soup.find_all('a', class_='highslide')

            # Store the links in a list
            set_links_list = [link['href'] for link in set_links]

            # Print the number of pages and the list of links for each year
            print(f"\nNumber of pages for {year_link}: {len(set_links_list)}")
            print("List of set links:")
            for set_link in set_links_list:
                print(set_link)
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# Number of pages in the category: 50
# List of category links:
# /sets/theme-Creator-Expert/year-2016
# /sets/theme-Creator-Expert/year-2016
# /sets/theme-Creator-Expert/year-2016
# /sets/theme-Creator-Expert/year-2016
# /sets/theme-Creator-Expert/year-2016
# /sets/theme-Creator-Expert/year-2016
# /sets/theme-Creator-Expert/year-2016
# /sets/theme-Creator-Expert/year-2016
# /sets/theme-Classic/year-2016
# /sets/theme-Classic/year-2016
# /sets/theme-Classic/year-2016
# /sets/theme-Classic/year-2016
# /sets/theme-Classic/year-2016
# /sets/theme-Classic/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Juniors/year-2016
# /sets/theme-Duplo/year-2016
# /sets/theme-Duplo/year-2016
# /sets/theme-Duplo/year-2016
# /sets/theme-Duplo/year-2016
# /sets/theme-Duplo/year-2016
# /sets/theme-Duplo/year-2016
# /sets/theme-Duplo/year-2016
# /sets/theme-Duplo/year-2016
# /sets/theme-Duplo/year-2016
# /sets/theme-Duplo/year-2016
# /sets/theme-Duplo/year-2016
# /sets/theme-Duplo/year-2016
# /sets/theme-Duplo/year-2016
# /sets/theme-Duplo/year-2016
# /sets/theme-Duplo/year-2016
# /sets/theme-Duplo/year-2016
#
# Number of pages for /sets/theme-Creator-Expert/year-2016: 4
# List of set links:
# https://images.brickset.com/sets/large/10251-1.jpg?201510121127
# https://images.brickset.com/sets/large/10252-1.jpg?201606140214
# https://images.brickset.com/sets/large/10253-1.jpg?201605190256
# https://images.brickset.com/sets/large/10254-1.jpg?201608110306
# https://images.brickset.com/sets/large/10809-1.jpg?201511230710
# https://images.brickset.com/sets/large/10810-1.jpg?201605201119
# https://images.brickset.com/sets/large/10811-1.jpg?201605201119
# https://images.brickset.com/sets/large/10812-1.jpg?201605201119
# https://images.brickset.com/sets/large/10813-1.jpg?201605201119
# https://images.brickset.com/sets/large/10814-1.jpg?201511230710
# https://images.brickset.com/sets/large/10815-1.jpg?201511230710
# https://images.brickset.com/sets/large/10816-1.jpg?201511230710
# https://images.brickset.com/sets/large/10817-1.jpg?201511230710
# https://images.brickset.com/sets/large/10818-1.jpg?201511230710
# https://images.brickset.com/sets/large/10819-1.jpg?201511230710
# https://images.brickset.com/sets/large/10820-1.jpg?201605201119
# https://images.brickset.com/sets/large/10822-1.jpg?201605201119
# https://images.brickset.com/sets/large/10824-1.jpg?201511230710
# https://images.brickset.com/sets/large/10825-1.jpg?201605201119
# https://images.brickset.com/sets/large/10826-1.jpg?201511230710
# https://images.brickset.com/sets/large/10827-1.jpg?201605200842

# %% [markdown]
# ## Step 2: Crawling information for product items (on all category pages)

# %%
import pprint
import requests
from bs4 import BeautifulSoup

lst_productinfos = []

lst_catelinks = ["http://brickset.com/sets/year-2016", "http://brickset.com/sets/year-2017"]

# Iterate through each category page
for url in lst_catelinks:
    # Send a GET request to the category page
    response = requests.get(url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content of the category page
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract information for each product item
        for divbox in soup.find_all("article", {"class": "set"}):
            try:
                oneproduct = {}
                oneproduct["Title"] = divbox.find("h1").get_text()
                oneproduct["Link"] = divbox.find("a").get("href")
                oneproduct["Theme"] = divbox.find("div", {"class": "tags"}).find_all("a")[1].get_text()
                oneproduct["Subtheme"] = divbox.find("div", {"class": "tags"}).find_all("a")[2].get_text()
                oneproduct["Year"] = divbox.find("div", {"class": "tags"}).find_all("a")[-1].get_text()

                # Add more attributes as needed

                lst_productinfos.append(oneproduct)
            except Exception as e:
                print(f"Error processing product on {url}: {e}")
    else:
        print(f"Failed to retrieve the page {url}. Status code: {response.status_code}")

# Print or do something with lst_productinfos
for product_info in lst_productinfos:
    pprint.pprint(product_info)
# Out:
# {'Link': 'https://images.brickset.com/sets/large/10251-1.jpg?201510121127',
#  'Subtheme': 'Modular Buildings Collection',
#  'Theme': 'Creator Expert',
#  'Title': 'Brick Bank',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10252-1.jpg?201606140214',
#  'Subtheme': 'Vehicles',
#  'Theme': 'Creator Expert',
#  'Title': 'Volkswagen Beetle',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10253-1.jpg?201605190256',
#  'Subtheme': 'Landmarks',
#  'Theme': 'Creator Expert',
#  'Title': 'Big Ben',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10254-1.jpg?201608110306',
#  'Subtheme': 'Winter Village Collection',
#  'Theme': 'Creator Expert',
#  'Title': 'Winter Holiday Train',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10654-1.jpg?201609271134',
#  'Subtheme': 'Creative Box',
#  'Theme': 'Classic',
#  'Title': 'XL Creative Brick Box',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10702-1.jpg?201511230710',
#  'Subtheme': 'Creative Building',
#  'Theme': 'Classic',
#  'Title': 'Creative Building Set',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10705-1.jpg?201605201119',
#  'Subtheme': 'Creative Building',
#  'Theme': 'Classic',
#  'Title': 'Creative Building Basket',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10720-1.jpg?201601050913',
#  'Subtheme': 'City',
#  'Theme': 'Juniors',
#  'Title': 'Police Helicopter Chase',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10721-1.jpg?201601050913',
#  'Subtheme': 'Marvel Super Heroes',
#  'Theme': 'Juniors',
#  'Title': 'Iron Man vs. Loki',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10722-1.jpg?201601050913',
#  'Subtheme': 'Ninjago',
#  'Theme': 'Juniors',
#  'Title': 'Snake Showdown',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10723-1.jpg?201601050913',
#  'Subtheme': 'Disney Princess',
#  'Theme': 'Juniors',
#  'Title': "Ariel's Dolphin Carriage",
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10724-1.jpg?201605201119',
#  'Subtheme': 'DC Comics Super Heroes',
#  'Theme': 'Juniors',
#  'Title': 'Batman & Superman vs. Lex Luthor',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10725-1.jpg?201601050913',
#  'Subtheme': 'Ninjago',
#  'Theme': 'Juniors',
#  'Title': 'Lost Temple',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10726-1.jpg?201605201119',
#  'Subtheme': 'Friends',
#  'Theme': 'Juniors',
#  'Title': "Stephanie's Horse Carriage",
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10727-1.jpg?201605201119',
#  'Subtheme': 'Friends',
#  'Theme': 'Juniors',
#  'Title': "Emma's Ice Cream Truck",
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10728-1.jpg?201605201119',
#  'Subtheme': 'Friends',
#  'Theme': 'Juniors',
#  'Title': "Mia's Vet Clinic",
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10729-1.jpg?201601050913',
#  'Subtheme': 'Disney Princess',
#  'Theme': 'Juniors',
#  'Title': "Cinderella's Carriage",
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10801-1.jpg?201511230710',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Baby Animals',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10802-1.jpg?201511230710',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Savanna',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10803-1.jpg?201511230710',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Arctic',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10804-1.jpg?201511230710',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Jungle',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10805-1.jpg?201601050913',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Around the World',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10806-1.jpg?201511230710',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Horses',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10807-1.jpg?201511230710',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Horse Trailer',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10808-1.jpg?201511230710',
#  'Subtheme': '2016',
#  'Theme': 'Duplo',
#  'Title': 'Little Plane',
#  'Year': '2016'}
# {'Link': 'https://images.brickset.com/sets/large/10255-1.jpg?201610170543',
#  'Subtheme': 'Modular Buildings Collection',
#  'Theme': 'Creator Expert',
#  'Title': 'Assembly Square',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10256-1.jpg?201710300126',
#  'Subtheme': 'Landmarks',
#  'Theme': 'Creator Expert',
#  'Title': 'Taj Mahal',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10257-1.jpg?201704270240',
#  'Subtheme': 'Fairground Collection',
#  'Theme': 'Creator Expert',
#  'Title': 'Carousel',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10258-1.jpg?201707030126',
#  'Subtheme': 'Vehicles',
#  'Theme': 'Creator Expert',
#  'Title': 'London Bus',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10259-1.jpg?201708220559',
#  'Subtheme': 'Winter Village Collection',
#  'Theme': 'Creator Expert',
#  'Title': 'Winter Village Station',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10703-1.jpg?201611300919',
#  'Subtheme': 'Creative Box',
#  'Theme': 'Classic',
#  'Title': 'Creative Builder Box',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10704-1.jpg?201611300919',
#  'Subtheme': 'Creative Box',
#  'Theme': 'Classic',
#  'Title': 'Creative Box',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10706-1.jpg?201611300919',
#  'Subtheme': 'Creative Box',
#  'Theme': 'Classic',
#  'Title': 'Blue Creative Box',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10707-1.jpg?201611300919',
#  'Subtheme': 'Creative Box',
#  'Theme': 'Classic',
#  'Title': 'Red Creative Box',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10708-1.jpg?201611300919',
#  'Subtheme': 'Creative Box',
#  'Theme': 'Classic',
#  'Title': 'Green Creative Box',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10709-1.jpg?201611300919',
#  'Subtheme': 'Creative Box',
#  'Theme': 'Classic',
#  'Title': 'Orange Creative Box',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10730-1.jpg?201705020831',
#  'Subtheme': 'Cars 3',
#  'Theme': 'Juniors',
#  'Title': 'Lightning McQueen Speed Launcher',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10731-1.jpg?201705020831',
#  'Subtheme': 'Cars 3',
#  'Theme': 'Juniors',
#  'Title': 'Cruz Ramirez Race Simulator',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10732-1.jpg?201705020831',
#  'Subtheme': 'Cars 3',
#  'Theme': 'Juniors',
#  'Title': "Guido and Luigi's Pit Stop",
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10733-1.jpg?201705020831',
#  'Subtheme': 'Cars 3',
#  'Theme': 'Juniors',
#  'Title': "Mater's Junkyard",
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10734-1.jpg?201611101158',
#  'Subtheme': 'City',
#  'Theme': 'Juniors',
#  'Title': 'Demolition Site',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10735-1.jpg?201611101158',
#  'Subtheme': 'City',
#  'Theme': 'Juniors',
#  'Title': 'Police Truck Chase',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10736-1.jpg?201611300919',
#  'Subtheme': 'Disney Princess',
#  'Theme': 'Juniors',
#  'Title': "Anna and Elsa's Frozen Playground",
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10737-1.jpg?201611300919',
#  'Subtheme': 'DC Comics Super Heroes',
#  'Theme': 'Juniors',
#  'Title': 'Batman vs. Mr. Freeze',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10738-1.jpg?201707030126',
#  'Subtheme': 'Disney Princess',
#  'Theme': 'Juniors',
#  'Title': "Snow White's Forest Cottage",
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10739-1.jpg?201707030126',
#  'Subtheme': 'Ninjago',
#  'Theme': 'Juniors',
#  'Title': 'Shark Attack',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10740-1.jpg?201611101158',
#  'Subtheme': 'City',
#  'Theme': 'Juniors',
#  'Title': 'Fire Patrol Suitcase',
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10742-1.jpg?201705020831',
#  'Subtheme': 'Cars 3',
#  'Theme': 'Juniors',
#  'Title': "Willy's Butte Speed Training",
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10743-1.jpg?201705020831',
#  'Subtheme': 'Cars 3',
#  'Theme': 'Juniors',
#  'Title': "Smokey's Garage",
#  'Year': '2017'}
# {'Link': 'https://images.brickset.com/sets/large/10744-1.jpg?201705020831',
#  'Subtheme': 'Cars 3',
#  'Theme': 'Juniors',
#  'Title': 'Thunder Hollow Crazy 8 Race',
#  'Year': '2017'}

# %% [markdown]
# ## Step 3 — Extracting Detail information from Product Page

# %% [markdown]
# Each product has a detail page. For example, https://brickset.com/sets/5659-1/The-Great-Train-Chase
# <img src="images/BrickDetail.jpg"><br>

# %%
# Assuming lst_productinfos is already populated from Step 2

for oneproduct in lst_productinfos:
    url = oneproduct["Link"]
    print(url)

    # Send a GET request to the product detail page
    response = requests.get(url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:

        # Parse the HTML content of the product detail page
        soup = BeautifulSoup(response.text, 'html.parser')

        # Write your code here to extract detailed information
        age_range_element = soup.find("div", {"class": "feature age"})

        # Check if the element exists before trying to extract information
        if age_range_element:
            age_range = age_range_element.find("dd").get_text()
            # Customize the code to extract other details as needed
            oneproduct["Age Range"] = age_range
        else:
            oneproduct["Age Range"] = "Not available"  # Or any default value

        # Add more attributes as needed

    else:
        print(f"Failed to retrieve the page {url}. Status code: {response.status_code}")

# Print or do something with updated lst_productinfos
for product_info in lst_productinfos:
    pprint.pprint(product_info)
# Out:
# https://images.brickset.com/sets/large/10251-1.jpg?201510121127
# https://images.brickset.com/sets/large/10252-1.jpg?201606140214
# https://images.brickset.com/sets/large/10253-1.jpg?201605190256
# https://images.brickset.com/sets/large/10254-1.jpg?201608110306
# https://images.brickset.com/sets/large/10654-1.jpg?201609271134
# https://images.brickset.com/sets/large/10702-1.jpg?201511230710
# https://images.brickset.com/sets/large/10705-1.jpg?201605201119
# https://images.brickset.com/sets/large/10720-1.jpg?201601050913
# https://images.brickset.com/sets/large/10721-1.jpg?201601050913
# https://images.brickset.com/sets/large/10722-1.jpg?201601050913
# https://images.brickset.com/sets/large/10723-1.jpg?201601050913
# https://images.brickset.com/sets/large/10724-1.jpg?201605201119
# https://images.brickset.com/sets/large/10725-1.jpg?201601050913
# https://images.brickset.com/sets/large/10726-1.jpg?201605201119
# https://images.brickset.com/sets/large/10727-1.jpg?201605201119
# https://images.brickset.com/sets/large/10728-1.jpg?201605201119
# https://images.brickset.com/sets/large/10729-1.jpg?201601050913
# https://images.brickset.com/sets/large/10801-1.jpg?201511230710
# https://images.brickset.com/sets/large/10802-1.jpg?201511230710
# https://images.brickset.com/sets/large/10803-1.jpg?201511230710
# https://images.brickset.com/sets/large/10804-1.jpg?201511230710
# https://images.brickset.com/sets/large/10805-1.jpg?201601050913
# https://images.brickset.com/sets/large/10806-1.jpg?201511230710
# https://images.brickset.com/sets/large/10807-1.jpg?201511230710
# https://images.brickset.com/sets/large/10808-1.jpg?201511230710
# https://images.brickset.com/sets/large/10255-1.jpg?201610170543
# https://images.brickset.com/sets/large/10256-1.jpg?201710300126
# https://images.brickset.com/sets/large/10257-1.jpg?201704270240
# https://images.brickset.com/sets/large/10258-1.jpg?201707030126
# https://images.brickset.com/sets/large/10259-1.jpg?201708220559
# https://images.brickset.com/sets/large/10703-1.jpg?201611300919
# https://images.brickset.com/sets/large/10704-1.jpg?201611300919
# https://images.brickset.com/sets/large/10706-1.jpg?201611300919
# https://images.brickset.com/sets/large/10707-1.jpg?201611300919
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-605cb02a1326> in <cell line: 3>()
#      12
#      13         # Parse the HTML content of the product detail page
# ---> 14         soup = BeautifulSoup(response.text, 'html.parser')
#      15
#      16         # Write your code here to extract detailed information
#
# /usr/local/lib/python3.10/dist-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     331             self.builder.initialize_soup(self)
#     332             try:
# --> 333                 self._feed()
#     334                 success = True
#     335                 break
#
# /usr/local/lib/python3.10/dist-packages/bs4/__init__.py in _feed(self)
#     450         self.builder.reset()
#     451
# --> 452         self.builder.feed(self.markup)
#     453         # Close out any unfinished strings and close all the open tags.
#     454         self.endData()
#
# /usr/local/lib/python3.10/dist-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     360         parser = BeautifulSoupHTMLParser(*args, **kwargs)
#     361         parser.soup = self.soup
# --> 362         parser.feed(markup)
#     363         parser.close()
#     364         parser.already_closed_empty_element = []
#
# /usr/lib/python3.10/html/parser.py in feed(self, data)
#     108         """
#     109         self.rawdata = self.rawdata + data
# --> 110         self.goahead(0)
#     111
#     112     def close(self):
#
# /usr/lib/python3.10/html/parser.py in goahead(self, end)
#     176                     k = self.parse_pi(i)
#     177                 elif startswith("<!", i):
# --> 178                     k = self.parse_html_declaration(i)
#     179                 elif (i + 1) < n:
#     180                     self.handle_data("<")
#
# /usr/lib/python3.10/html/parser.py in parse_html_declaration(self, i)
#     261             return self.parse_comment(i)
#     262         elif rawdata[i:i+3] == '<![':
# --> 263             return self.parse_marked_section(i)
#     264         elif rawdata[i:i+9].lower() == '<!doctype':
#     265             # find the closing >
#
# /usr/lib/python3.10/_markupbase.py in parse_marked_section(self, i, report)
#     152             match= _msmarkedsectionclose.search(rawdata, i+3)
#     153         else:
# --> 154             raise AssertionError(
#     155                 'unknown status keyword %r in marked section' % rawdata[i+3:j]
#     156             )
#
# AssertionError: unknown status keyword 'Q' in marked section

# %% [markdown]
# The link of page has been stored in **lst_productinfos**.<br>
# Save result into JSON file as pretty format

# %% [markdown]
# Save result into CSV file with struct: Title, Link, Theme, Subtheme, Pieces, Packaging, Price, Set Type

# %% [markdown]
# # Crawl images to build image dataset

# %% [markdown]
# Let's start from http://brickset.com/sets/year-2016 <br>
# <img src="images/BrickBankImage.jpg"><br>
# From each product information, let's navigate to extract src information from img node.<br>
# Then, download image and save into folder **images/**

# %%
urlimg  = 'https://images.brickset.com/sets/large/5655-1.jpg?201009110931'
imgfname= 'images/5655-1.jpg'

import urllib.request
response = urllib.request.urlopen(urlimg)
imagesrc = response.read()
f = open(imgfname, 'wb')
f.write( imagesrc )
f.close()

# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Function to download and save an image
def download_image(image_url, image_filename):
    try:
        response = requests.get(image_url)
        if response.status_code == 200:
            with open(image_filename, 'wb') as f:
                f.write(response.content)
            print(f"Downloaded and saved: {image_filename}")
        else:
            print(f"Failed to download image from {image_url}. Status code: {response.status_code}")
    except Exception as e:
        print(f"Error downloading image: {e}")

# URL of the starting page
base_url = 'http://brickset.com/sets/year-2016'
response = requests.get(base_url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Create a folder to store images if it doesn't exist
    image_folder = 'images'
    if not os.path.exists(image_folder):
        os.makedirs(image_folder)

    # Extract product information and download images
    for set_box in soup.find_all("article", {"class": "set"}):
        try:
            title = set_box.find("h1").get_text()
            image_url = set_box.find("img")['src']
            image_filename = os.path.join(image_folder, f"{title}.jpg")

            # Download and save the image
            download_image(image_url, image_filename)
        except Exception as e:
            print(f"Error processing set: {e}")
else:
    print(f"Failed to retrieve the page {base_url}. Status code: {response.status_code}")
# Out:
# Downloaded and saved: images/Brick Bank.jpg
# Downloaded and saved: images/Volkswagen Beetle.jpg
# Downloaded and saved: images/Big Ben.jpg
# Downloaded and saved: images/Winter Holiday Train.jpg
# Downloaded and saved: images/XL Creative Brick Box.jpg
# Downloaded and saved: images/Creative Building Set.jpg
# Downloaded and saved: images/Creative Building Basket.jpg
# Downloaded and saved: images/Police Helicopter Chase.jpg
# Downloaded and saved: images/Iron Man vs. Loki.jpg
# Downloaded and saved: images/Snake Showdown.jpg
# Downloaded and saved: images/Ariel's Dolphin Carriage.jpg
# Downloaded and saved: images/Batman & Superman vs. Lex Luthor.jpg
# Downloaded and saved: images/Lost Temple.jpg
# Downloaded and saved: images/Stephanie's Horse Carriage.jpg
# Downloaded and saved: images/Emma's Ice Cream Truck.jpg
# Downloaded and saved: images/Mia's Vet Clinic.jpg
# Downloaded and saved: images/Cinderella's Carriage.jpg
# Downloaded and saved: images/Baby Animals.jpg
# Downloaded and saved: images/Savanna.jpg
# Downloaded and saved: images/Arctic.jpg
# Downloaded and saved: images/Jungle.jpg
# Downloaded and saved: images/Around the World.jpg
# Downloaded and saved: images/Horses.jpg
# Downloaded and saved: images/Horse Trailer.jpg
# Downloaded and saved: images/Little Plane.jpg
